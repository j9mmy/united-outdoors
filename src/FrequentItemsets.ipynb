# %% [markdown]
# # Practicumopdrachten Week 9.2 (eerste kans)

# %%
from loguru import logger # pip install loguru
import warnings
import pandas as pd
import sqlite3
from mlxtend.frequent_patterns import apriori, association_rules
warnings.simplefilter('ignore')

# %%
# SQLite Connecties
logger.info('Establishing connection with SQLite databases...')
conn = sqlite3.connect('../data/processed/United_Outdoors.sqlite3')
logger.success('Connections established!')

# Connect to the SQLite database
cursor = conn.cursor()
# Out:
# 2024-05-26 08:44:11.852 | INFO     | __main__:<module>:2 - Establishing connection with SQLite databases...
# 2024-05-26 08:44:11.852 | SUCCESS  | __main__:<module>:4 - Connections established!

# %%
orders = pd.read_sql_query('''
    SELECT id, SalesOrderID, OrderID, Quantity, OrderQty, ModifiedDate, ProductID_AW, ProductID_NW
    FROM Order_Details
''', conn)

products = pd.read_sql_query('''
    SELECT Name, ProductID_AW, ProductID_NW
    FROM Product p 
''', conn)

# %%
minsup = 0.00000000001
minconf = 0.000001

# %%
orders['ModifiedDate'] = pd.to_datetime(orders['ModifiedDate'])
orders = orders.sort_values('ModifiedDate').drop_duplicates(['SalesOrderID', 'OrderID'], keep='last')
orders['Quantity'] = orders['Quantity'].combine_first(orders['OrderQty'])
ordered_products = pd.merge(orders, products, on=['ProductID_AW', 'ProductID_NW'], how='inner')
ordered_products = ordered_products[['id', 'Name', 'Quantity']]

ordered_products
# Out:
#            id                             Name  Quantity
# 0       82758            Road-350-W Yellow, 44       4.0
# 1       24185           Mountain-200 Black, 38       1.0
# 2       24186                 Road-250 Red, 58       1.0
# 3       24187               Road-650 Black, 52       1.0
# 4       24188            Road-550-W Yellow, 40       1.0
# ...       ...                              ...       ...
# 32309  110264               Mountain Tire Tube       1.0
# 32310  110266            Water Bottle - 30 oz.       1.0
# 32311  110268                   Road Tire Tube       1.0
# 32312  110301           Mountain-200 Black, 46       1.0
# 32313  124122  Original Frankfurter grüne Soße       2.0
#
# [32314 rows x 3 columns]

# %%
# implement the apriori algorithm
basket = (ordered_products
          .groupby(['id', 'Name'])['Quantity']
          .count().unstack().reset_index().fillna(0)
          .set_index('id'))
basket.head()
# Out:
# Name  AWC Logo Cap  Alice Mutton  All-Purpose Bike Stand  Aniseed Syrup  \
# id
# 2              0.0           0.0                     0.0            0.0
# 14             0.0           0.0                     0.0            0.0
# 29             0.0           0.0                     0.0            0.0
# 32             0.0           0.0                     0.0            0.0
# 52             0.0           0.0                     0.0            0.0
#
# Name  Baseball Cap  Bike Wash - Dissolver  Boston Crab Meat  Cable Lock  \
# id
# 2              0.0                    0.0               0.0         0.0
# 14             0.0                    0.0               0.0         0.0
# 29             0.0                    0.0               0.0         0.0
# 32             0.0                    0.0               0.0         0.0
# 52             0.0                    0.0               0.0         0.0
#
# Name  Camembert Pierrot  Carnarvon Tigers  ...  Visor  Water Bottle - 30 oz.  \
# id                                         ...
# 2                   0.0               0.0  ...    0.0                    0.0
# 14                  0.0               0.0  ...    0.0                    0.0
# 29                  0.0               0.0  ...    0.0                    0.0
# 32                  0.0               0.0  ...    0.0                    0.0
# 52                  0.0               0.0  ...    0.0                    0.0
#
# Name  Wimmers gute Semmelknödel  Women's Mountain Shorts, L  \
# id
# 2                           0.0                         0.0
# 14                          0.0                         0.0
# 29                          0.0                         0.0
# 32                          0.0                         0.0
# 52                          0.0                         0.0
#
# Name  Women's Mountain Shorts, M  Women's Mountain Shorts, S  \
# id
# 2                            0.0                         0.0
# 14                           0.0                         0.0
# 29                           0.0                         0.0
# 32                           0.0                         0.0
# 52                           0.0                         0.0
#
# Name  Women's Tights, L  Women's Tights, M  Women's Tights, S  Zaanse koeken
# id
# 2                   0.0                0.0                0.0            0.0
# 14                  0.0                0.0                0.0            0.0
# 29                  0.0                0.0                0.0            0.0
# 32                  0.0                0.0                0.0            0.0
# 52                  0.0                0.0                0.0            0.0
#
# [5 rows x 343 columns]

# %%
# hot encode the basket
def hot_encode(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
basket_sets = basket.applymap(hot_encode)
basket_sets
# Out:
# Name    AWC Logo Cap  Alice Mutton  All-Purpose Bike Stand  Aniseed Syrup  \
# id
# 2                  0             0                       0              0
# 14                 0             0                       0              0
# 29                 0             0                       0              0
# 32                 0             0                       0              0
# 52                 0             0                       0              0
# ...              ...           ...                     ...            ...
# 124089             0             0                       0              0
# 124091             0             0                       0              0
# 124093             0             0                       0              0
# 124095             0             0                       0              0
# 124122             0             0                       0              0
#
# Name    Baseball Cap  Bike Wash - Dissolver  Boston Crab Meat  Cable Lock  \
# id
# 2                  0                      0                 0           0
# 14                 0                      0                 0           0
# 29                 0                      0                 0           0
# 32                 0                      0                 0           0
# 52                 0                      0                 0           0
# ...              ...                    ...               ...         ...
# 124089             0                      0                 0           0
# 124091             0                      0                 0           0
# 124093             0                      0                 0           0
# 124095             0                      0                 0           0
# 124122             0                      0                 0           0
#
# Name    Camembert Pierrot  Carnarvon Tigers  ...  Visor  \
# id                                           ...
# 2                       0                 0  ...      0
# 14                      0                 0  ...      0
# 29                      0                 0  ...      0
# 32                      0                 0  ...      0
# 52                      0                 0  ...      0
# ...                   ...               ...  ...    ...
# 124089                  0                 0  ...      0
# 124091                  0                 0  ...      0
# 124093                  0                 0  ...      0
# 124095                  0                 0  ...      0
# 124122                  0                 0  ...      0
#
# Name    Water Bottle - 30 oz.  Wimmers gute Semmelknödel  \
# id
# 2                           0                          0
# 14                          0                          0
# 29                          0                          0
# 32                          0                          0
# 52                          0                          0
# ...                       ...                        ...
# 124089                      0                          0
# 124091                      0                          0
# 124093                      0                          0
# 124095                      0                          0
# 124122                      0                          0
#
# Name    Women's Mountain Shorts, L  Women's Mountain Shorts, M  \
# id
# 2                                0                           0
# 14                               0                           0
# 29                               0                           0
# 32                               0                           0
# 52                               0                           0
# ...                            ...                         ...
# 124089                           0                           0
# 124091                           0                           0
# 124093                           0                           0
# 124095                           0                           0
# 124122                           0                           0
#
# Name    Women's Mountain Shorts, S  Women's Tights, L  Women's Tights, M  \
# id
# 2                                0                  0                  0
# 14                               0                  0                  0
# 29                               0                  0                  0
# 32                               0                  0                  0
# 52                               0                  0                  0
# ...                            ...                ...                ...
# 124089                           0                  0                  0
# 124091                           0                  0                  0
# 124093                           0                  0                  0
# 124095                           0                  0                  0
# 124122                           0                  0                  0
#
# Name    Women's Tights, S  Zaanse koeken
# id
# 2                       0              0
# 14                      0              0
# 29                      0              0
# 32                      0              0
# 52                      0              0
# ...                   ...            ...
# 124089                  0              0
# 124091                  0              0
# 124093                  0              0
# 124095                  0              0
# 124122                  0              0
#
# [32296 rows x 343 columns]

# %%
# generate frequent itemsets
frequent_itemsets = apriori(basket_sets, minsup, use_colnames=True)
frequent_itemsets
# Out:
#       support                      itemsets
# 0    0.019352                (AWC Logo Cap)
# 1    0.000774                (Alice Mutton)
# 2    0.001610      (All-Purpose Bike Stand)
# 3    0.000248               (Aniseed Syrup)
# 4    0.006471       (Bike Wash - Dissolver)
# ..        ...                           ...
# 333  0.007834  (Women's Mountain Shorts, S)
# 334  0.000774           (Women's Tights, L)
# 335  0.000186           (Women's Tights, M)
# 336  0.000867           (Women's Tights, S)
# 337  0.000155               (Zaanse koeken)
#
# [338 rows x 2 columns]

# %%
# generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
rules = rules[rules['confidence'] >= minconf]

rules
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
