# %% [markdown]
# # Practicumopdrachten Week 9.2 (eerste kans)

# %%
from loguru import logger # pip install loguru
import warnings
import pandas as pd
import sqlite3
from mlxtend.frequent_patterns import apriori, association_rules
warnings.simplefilter('ignore')

# %%
# SQLite Connecties
logger.info('Establishing connection with SQLite databases...')
conn = sqlite3.connect('../data/processed/United_Outdoors.sqlite3')
logger.success('Connections established!')

# Connect to the SQLite database
cursor = conn.cursor()
# Out:
# 2024-05-26 12:52:52.775 | INFO     | __main__:<module>:2 - Establishing connection with SQLite databases...
# 2024-05-26 12:52:52.775 | SUCCESS  | __main__:<module>:4 - Connections established!

# %%
AW_ordered_products = pd.read_sql_query('''
    SELECT o.SalesOrderID, p.Name, o.OrderQty
    FROM Order_Details o
    INNER JOIN 'product' p ON p.ProductID_AW = o.ProductID_AW                             
''', conn)

NW_ordered_products = pd.read_sql_query('''
    SELECT o.OrderID, p.Name, o.Quantity
    FROM Order_Details o
    INNER JOIN 'product' p ON p.ProductID_NW = o.ProductID_NW                             
''', conn)

AW_ordered_products = AW_ordered_products.rename(columns={'SalesOrderID': 'OrderID', 'OrderQty': 'Quantity'})

ordered_products = pd.concat([AW_ordered_products, NW_ordered_products], ignore_index=True)

ordered_products = ordered_products.drop_duplicates()

# %%
minsup = 0.01
minconf = 0.01

# %%
# implement the apriori algorithm
basket = (ordered_products
          .groupby(['OrderID', 'Name'])['Quantity']
          .count().unstack().reset_index().fillna(0)
          .set_index('OrderID'))
basket.head()
# Out:
# Name     AWC Logo Cap  Alice Mutton  All-Purpose Bike Stand  Aniseed Syrup  \
# OrderID
# 10248.0           0.0           0.0                     0.0            0.0
# 10249.0           0.0           0.0                     0.0            0.0
# 10250.0           0.0           0.0                     0.0            0.0
# 10251.0           0.0           0.0                     0.0            0.0
# 10252.0           0.0           0.0                     0.0            0.0
#
# Name     Bike Wash - Dissolver  Boston Crab Meat  Cable Lock  \
# OrderID
# 10248.0                    0.0               0.0         0.0
# 10249.0                    0.0               0.0         0.0
# 10250.0                    0.0               0.0         0.0
# 10251.0                    0.0               0.0         0.0
# 10252.0                    0.0               0.0         0.0
#
# Name     Camembert Pierrot  Carnarvon Tigers  Chai  ...  Vegie-spread  \
# OrderID                                             ...
# 10248.0                0.0               0.0   0.0  ...           0.0
# 10249.0                0.0               0.0   0.0  ...           0.0
# 10250.0                0.0               0.0   0.0  ...           0.0
# 10251.0                0.0               0.0   0.0  ...           0.0
# 10252.0                1.0               0.0   0.0  ...           0.0
#
# Name     Water Bottle - 30 oz.  Wimmers gute Semmelknödel  \
# OrderID
# 10248.0                    0.0                        0.0
# 10249.0                    0.0                        0.0
# 10250.0                    0.0                        0.0
# 10251.0                    0.0                        0.0
# 10252.0                    0.0                        0.0
#
# Name     Women's Mountain Shorts, L  Women's Mountain Shorts, M  \
# OrderID
# 10248.0                         0.0                         0.0
# 10249.0                         0.0                         0.0
# 10250.0                         0.0                         0.0
# 10251.0                         0.0                         0.0
# 10252.0                         0.0                         0.0
#
# Name     Women's Mountain Shorts, S  Women's Tights, L  Women's Tights, M  \
# OrderID
# 10248.0                         0.0                0.0                0.0
# 10249.0                         0.0                0.0                0.0
# 10250.0                         0.0                0.0                0.0
# 10251.0                         0.0                0.0                0.0
# 10252.0                         0.0                0.0                0.0
#
# Name     Women's Tights, S  Zaanse koeken
# OrderID
# 10248.0                0.0            0.0
# 10249.0                0.0            0.0
# 10250.0                0.0            0.0
# 10251.0                0.0            0.0
# 10252.0                0.0            0.0
#
# [5 rows x 343 columns]

# %%
# hot encode the basket
def hot_encode(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
    
basket_sets = basket.applymap(hot_encode)
basket_sets
# Out:
# Name     AWC Logo Cap  Alice Mutton  All-Purpose Bike Stand  Aniseed Syrup  \
# OrderID
# 10248.0             0             0                       0              0
# 10249.0             0             0                       0              0
# 10250.0             0             0                       0              0
# 10251.0             0             0                       0              0
# 10252.0             0             0                       0              0
# ...               ...           ...                     ...            ...
# 75119.0             0             0                       0              0
# 75120.0             1             0                       0              0
# 75121.0             0             0                       0              0
# 75122.0             1             0                       0              0
# 75123.0             1             0                       1              0
#
# Name     Bike Wash - Dissolver  Boston Crab Meat  Cable Lock  \
# OrderID
# 10248.0                      0                 0           0
# 10249.0                      0                 0           0
# 10250.0                      0                 0           0
# 10251.0                      0                 0           0
# 10252.0                      0                 0           0
# ...                        ...               ...         ...
# 75119.0                      0                 0           0
# 75120.0                      0                 0           0
# 75121.0                      0                 0           0
# 75122.0                      0                 0           0
# 75123.0                      0                 0           0
#
# Name     Camembert Pierrot  Carnarvon Tigers  Chai  ...  Vegie-spread  \
# OrderID                                             ...
# 10248.0                  0                 0     0  ...             0
# 10249.0                  0                 0     0  ...             0
# 10250.0                  0                 0     0  ...             0
# 10251.0                  0                 0     0  ...             0
# 10252.0                  1                 0     0  ...             0
# ...                    ...               ...   ...  ...           ...
# 75119.0                  0                 0     0  ...             0
# 75120.0                  0                 0     0  ...             0
# 75121.0                  0                 0     0  ...             0
# 75122.0                  0                 0     0  ...             0
# 75123.0                  0                 0     0  ...             0
#
# Name     Water Bottle - 30 oz.  Wimmers gute Semmelknödel  \
# OrderID
# 10248.0                      0                          0
# 10249.0                      0                          0
# 10250.0                      0                          0
# 10251.0                      0                          0
# 10252.0                      0                          0
# ...                        ...                        ...
# 75119.0                      0                          0
# 75120.0                      0                          0
# 75121.0                      0                          0
# 75122.0                      0                          0
# 75123.0                      0                          0
#
# Name     Women's Mountain Shorts, L  Women's Mountain Shorts, M  \
# OrderID
# 10248.0                           0                           0
# 10249.0                           0                           0
# 10250.0                           0                           0
# 10251.0                           0                           0
# 10252.0                           0                           0
# ...                             ...                         ...
# 75119.0                           0                           0
# 75120.0                           0                           0
# 75121.0                           0                           0
# 75122.0                           0                           0
# 75123.0                           0                           0
#
# Name     Women's Mountain Shorts, S  Women's Tights, L  Women's Tights, M  \
# OrderID
# 10248.0                           0                  0                  0
# 10249.0                           0                  0                  0
# 10250.0                           0                  0                  0
# 10251.0                           0                  0                  0
# 10252.0                           0                  0                  0
# ...                             ...                ...                ...
# 75119.0                           0                  0                  0
# 75120.0                           0                  0                  0
# 75121.0                           0                  0                  0
# 75122.0                           0                  0                  0
# 75123.0                           0                  0                  0
#
# Name     Women's Tights, S  Zaanse koeken
# OrderID
# 10248.0                  0              0
# 10249.0                  0              0
# 10250.0                  0              0
# 10251.0                  0              0
# 10252.0                  0              0
# ...                    ...            ...
# 75119.0                  0              0
# 75120.0                  0              0
# 75121.0                  0              0
# 75122.0                  0              0
# 75123.0                  0              0
#
# [32295 rows x 343 columns]

# %%
# Generate frequent itemsets
frequent_itemsets = apriori(basket_sets, min_support=minsup, use_colnames=True)

frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.104722                                     (AWC Logo Cap)
# 1     0.041090                            (Bike Wash - Dissolver)
# 2     0.017185                                  (Classic Vest, M)
# 3     0.021118                                  (Classic Vest, S)
# 4     0.065676                            (Fender Set - Mountain)
# ...        ...                                                ...
# 1853  0.010094  (Long-Sleeve Logo Jersey, L, Water Bottle - 30...
# 1854  0.010063  (Long-Sleeve Logo Jersey, L, Water Bottle - 30...
# 1855  0.010033  (Long-Sleeve Logo Jersey, L, Water Bottle - 30...
# 1856  0.010094  (Long-Sleeve Logo Jersey, L, Water Bottle - 30...
# 1857  0.010002  (Long-Sleeve Logo Jersey, L, Water Bottle - 30...
#
# [1858 rows x 2 columns]

# %%
# generate association rules
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules = rules.sort_values(['confidence', 'lift'], ascending=[False, False])
rules = rules[rules['confidence'] >= minconf]

rules
# Out:
#                                              antecedents  \
# 9773    (Classic Vest, M, Classic Vest, S, AWC Logo Cap)
# 13701  (Bike Wash - Dissolver, Classic Vest, M, Class...
# 14993  (Sport-100 Helmet, Black, Bike Wash - Dissolve...
# 15021  (Bike Wash - Dissolver, Classic Vest, S, Sport...
# 16341  (Classic Vest, M, Classic Vest, S, Hitch Rack ...
# ...                                                  ...
# 9881                             (Water Bottle - 30 oz.)
# 16422                            (Water Bottle - 30 oz.)
# 16452                            (Water Bottle - 30 oz.)
# 33617                            (Water Bottle - 30 oz.)
# 5827                             (Water Bottle - 30 oz.)
#
#                                              consequents  antecedent support  \
# 9773   (Short-Sleeve Classic Jersey, XL, Short-Sleeve...            0.010063
# 13701  (Short-Sleeve Classic Jersey, XL, Short-Sleeve...            0.010094
# 14993  (Short-Sleeve Classic Jersey, XL, Short-Sleeve...            0.010559
# 15021  (Short-Sleeve Classic Jersey, XL, Short-Sleeve...            0.010373
# 16341  (Short-Sleeve Classic Jersey, XL, Short-Sleeve...            0.010002
# ...                                                  ...                 ...
# 9881   (AWC Logo Cap, Short-Sleeve Classic Jersey, XL...            0.145162
# 16422  (Long-Sleeve Logo Jersey, L, Classic Vest, M, ...            0.145162
# 16452  (Long-Sleeve Logo Jersey, L, Short-Sleeve Clas...            0.145162
# 33617  (Long-Sleeve Logo Jersey, L, Classic Vest, M, ...            0.145162
# 5827   (Sport-100 Helmet, Black, Classic Vest, M, Sho...            0.145162
#
#        consequent support   support  confidence       lift  leverage  \
# 9773             0.011736  0.010063    1.000000  85.211082  0.009945
# 13701            0.011736  0.010094    1.000000  85.211082  0.009976
# 14993            0.011736  0.010559    1.000000  85.211082  0.010435
# 15021            0.011736  0.010373    1.000000  85.211082  0.010251
# 16341            0.011736  0.010002    1.000000  85.211082  0.009884
# ...                   ...       ...         ...        ...       ...
# 9881             0.010125  0.010002    0.068899   6.804598  0.008532
# 16422            0.010125  0.010002    0.068899   6.804598  0.008532
# 16452            0.010125  0.010002    0.068899   6.804598  0.008532
# 33617            0.010125  0.010002    0.068899   6.804598  0.008532
# 5827             0.010156  0.010002    0.068899   6.783852  0.008527
#
#        conviction  zhangs_metric
# 9773          inf       0.998311
# 13701         inf       0.998342
# 14993         inf       0.998811
# 15021         inf       0.998623
# 16341         inf       0.998248
# ...           ...            ...
# 9881     1.063123       0.997897
# 16422    1.063123       0.997897
# 16452    1.063123       0.997897
# 33617    1.063123       0.997897
# 5827     1.063090       0.997371
#
# [71234 rows x 10 columns]
